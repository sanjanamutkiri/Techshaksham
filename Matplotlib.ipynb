# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.plot(x_axis,y_axis,color='g')
plt.show()

# %%
x_axis=[2,4,6,8]
y_axis=[1,10,100,1000]

# %%
plt.plot(x_axis,y_axis,marker='x')
plt.show()

# %%
x1_axis=[2,4,6,8]
y1_axis=[1,10,100,1000]
x2_axis=[2,4,6,8]
y2_axis=[80,34,40,10]
plt.plot(x1_axis,y1_axis,color='g')
plt.plot(x2_axis,y2_axis,color='r')
plt.legend(['expo','linear'])

# %% [markdown]
# ###

# %%
values=[10,15,20,10,15]
plt.hist(values,width=1)
plt.show()

# %%
value=[10,15,20,20]
plt.bar(value,[0.5,1,2,3],width=2)
plt.legend(['vales','occu'])
plt.title('bar chart')
# Out:
# Text(0.5, 1.0, 'bar chart')

# %%
#pie chart


values=[20,20,35,25]
plt.pie(values)
plt.show()

# %%
plt.pie(values,labels=['item1','item2','item3','item4'])
# Out:
# ([<matplotlib.patches.Wedge at 0x280c58d7290>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'item1'),
#   Text(-0.3399187231970732, 1.046162158377023, 'item2'),
#   Text(-0.9801071672559598, -0.49938956806635265, 'item3'),
#   Text(0.7778174593052022, -0.7778174593052025, 'item4')])

# %%
plt.pie(values,labels=['item1','item2','item3','item4'],
       explode=[0.0,0.0,0.2,0.0])

plt.show()

# %%
x=list(range(1,11))
y=[15,12,45,78,32,17,19,45,90,17]

# %%
plt.scatter(x,y,c=x)
plt.xlabel('demand')
plt.ylabel('price')
plt.title('scatter plot')
plt.show()

# %%
from matplotlib import cm
dir(
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Grays',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
# ...

# %%
plt.scatter(x,y,c=x,cmap='winter_r')
plt.xlabel('demand')
plt.ylabel('price')
plt.title('scatter plot')
plt.show()

# %%
#handling dates

# %%
dates=['2022-01-01','2021-01-03','2020-01-01','2019-01-01']
values=[100,101,102,60]
plt.xticks(rotation=45)
plt.plot(dates,values,c='g')
plt.show()

# %%
x1=[2,4,6,8]
y1=[1,10,100,1000]
x2=[1,3,5,7]
y2=[80,100,140,20]

# %%
plt.subplot(1,2,1)
plt.title('expo')
plt.plot(x1,y1,'r')


plt.subplot(1,2,2)
plt.title('negatively skwed')
plt.plot(x2,y2,'g')
#plt.tight_layout()


plt.show()
