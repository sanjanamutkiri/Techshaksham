# %%
import pandas as pd

# %%
df=pd.read_csv('cereals.csv')

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   calories  10 non-null     int64
#  2   protein   10 non-null     int64
#  3   vitamins  10 non-null     int64
#  4   rating    10 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 480.0+ bytes

# %%
df.set_index('name')
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
#df.set_index('name',inplace=True') make change in original df

# %%
df.head()
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.tail()
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
df.get('name')
# Out:
# 0                    100% Bran
# 1            100% Natural Bran
# 2                     All-Bran
# 3    All-Bran with Extra Fiber
# 4               Almond Delight
# 5      Apple Cinnamon Cheerios
# 6                  Apple Jacks
# 7                      Basic 4
# 8                    Bran Chex
# 9                  Bran Flakes
# Name: name, dtype: object

# %%
df.count()
# Out:
# name        10
# calories    10
# protein     10
# vitamins    10
# rating      10
# dtype: int64

# %%
df.isnull()
# Out:
#     name  calories  protein  vitamins  rating
# 0  False     False    False     False   False
# 1  False     False    False     False   False
# 2  False     False    False     False   False
# 3  False     False    False     False   False
# 4  False     False    False     False   False
# 5  False     False    False     False   False
# 6  False     False    False     False   False
# 7  False     False    False     False   False
# 8  False     False    False     False   False
# 9  False     False    False     False   False

# %%
df.count().isnull()
# Out:
# name        False
# calories    False
# protein     False
# vitamins    False
# rating      False
# dtype: bool

# %%
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories':'rating'] #error

# %%
df['calories','rating'] #single dimesnsion series will return give error

# %%
df[['calories','rating','name']]
# Out:
#    calories     rating                       name
# 0        70  68.402973                  100% Bran
# 1       120  33.983679          100% Natural Bran
# 2        70  59.425505                   All-Bran
# 3        50  93.704912  All-Bran with Extra Fiber
# 4       110  34.384843             Almond Delight
# 5       110  29.509541    Apple Cinnamon Cheerios
# 6       110  33.174094                Apple Jacks
# 7       130  37.038562                    Basic 4
# 8        90  49.120253                  Bran Chex
# 9        90  53.313813                Bran Flakes

# %%
df['name']
# Out:
# 0                    100% Bran
# 1            100% Natural Bran
# 2                     All-Bran
# 3    All-Bran with Extra Fiber
# 4               Almond Delight
# 5      Apple Cinnamon Cheerios
# 6                  Apple Jacks
# 7                      Basic 4
# 8                    Bran Chex
# 9                  Bran Flakes
# Name: name, dtype: object

# %%
cond=df['calories']>70

# %%
cond
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: calories, dtype: bool

# %%
df[cond]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
condp=df['protein']>=3

# %%
condp
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# Name: protein, dtype: bool

# %%
df[condp]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 7                    Basic 4       130        3        25  37.038562
# 9                Bran Flakes        90        3        25  53.313813

# %%
df[(df['calories']>70 ) & (df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253

# %%
df[(df['calories']>70 ) | (df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.loc[[2],['protein']]
# Out:
#    protein
# 2        4

# %%
df.loc[0:3,['protein','rating']]
# Out:
#    protein     rating
# 0        4  68.402973
# 1        3  33.983679
# 2        4  59.425505
# 3        4  93.704912

# %%
df.loc[0:4,'name':]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.iloc[0:5,0:3]
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[[0,2,4],0:3]
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1.loc[4]=['sanjana',100,4,35,93.45]

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                    sanjana       100        4        35  93.450000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                    sanjana       100        4        35  93.450000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1.loc[4]=['corn flakes',100,5,25,67.89]

# %% [markdown]
# df1

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1=df.iloc[0:5,].copy()

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000

# %%
df1.drop(3,axis=0,inplace=True)

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 4        corn flakes       100        5        25  67.890000

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df2=pd.DataFrame(df)

# %%
df2
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df2.drop(3,inplace=True)

# %%
df2
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 1        100% Natural Bran       120        3         0  33.983679
# 2                 All-Bran        70        4        25  59.425505
# 4              corn flakes       100        5        25  67.890000
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df2.drop('rating',axis=1,inplace=True)

# %% [markdown]
# ##

# %%
df2
# Out:
#    calories  protein  vitamins
# 0        70        4        25
# 1       120        3         0
# 2        70        4        25
# 4       100        5        25
# 5       110        2        25
# 6       110        2        25
# 7       130        3        25
# 8        90        2        25
# 9        90        3        25

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df2
# Out:
#    calories  protein  vitamins
# 0        70        4        25
# 1       120        3         0
# 2        70        4        25
# 4       100        5        25
# 5       110        2        25
# 6       110        2        25
# 7       130        3        25
# 8        90        2        25
# 9        90        3        25

# %%
df2.drop('vitamins',axis=1,inplace=True)

# %%
df2
# Out:
#    calories  protein
# 0        70        4
# 1       120        3
# 2        70        4
# 4       100        5
# 5       110        2
# 6       110        2
# 7       130        3
# 8        90        2
# 9        90        3

# %%
df1['my new column']=[1,2,3,4]

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating  my new column
# 0          100% Bran        70        4        25  68.402973              1
# 1  100% Natural Bran       120        3         0  33.983679              2
# 2           All-Bran        70        4        25  59.425505              3
# 4        corn flakes       100        5        25  67.890000              4

# %%
ascending_df=df.sort_values(by='calories')

# %%
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 4                corn flakes       100        5        25  67.890000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
ascending_df=df.sort_values(by='protein')
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                corn flakes       100        5        25  67.890000

# %%
desc_df=df.sort_values(by='protein',ascending=False)

# %%
desc_df
# Out:
#                         name  calories  protein  vitamins     rating
# 4                corn flakes       100        5        25  67.890000
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562
# 9                Bran Flakes        90        3        25  53.313813
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253

# %%
df.columns
# Out:
# Index(['name', 'calories', 'protein', 'vitamins', 'rating'], dtype='object')

# %%
df.columns=['col1','col2','col3','col4','col5']

# %%
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                corn flakes   100     5    25  67.890000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
df.to_csv('myCrealesFile.csv',index_label=False)

# %%
newdf=pd.read_csv('myCrealesFile.csv')

# %%
newdf
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                corn flakes   100     5    25  67.890000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
df2=df[5:8].copy()

# %%
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating  my new column
# 0          100% Bran        70        4        25  68.402973              1
# 1  100% Natural Bran       120        3         0  33.983679              2
# 2           All-Bran        70        4        25  59.425505              3
# 4        corn flakes       100        5        25  67.890000              4

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating  my new column
# 0          100% Bran        70        4        25  68.402973              1
# 1  100% Natural Bran       120        3         0  33.983679              2
# 2           All-Bran        70        4        25  59.425505              3
# 4        corn flakes       100        5        25  67.890000              4

# %%
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                corn flakes   100     5    25  67.890000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
df2=df[5:8].copy()

# %%
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
df2=df2.reset_index(drop=True)

# %%
df2
# Out:
#    index                     col1  col2  col3  col4       col5
# 0      5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 1      6              Apple Jacks   110     2    25  33.174094
# 2      7                  Basic 4   130     3    25  37.038562

# %%
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                corn flakes   100     5    25  67.890000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %% [markdown]
# ## df2.drop('index',axis=1)

# %%
df2.drop('index',axis=1,inplace=True)

# %%
df2
# Out:
#                       col1  col2  col3  col4       col5
# 0  Apple Cinnamon Cheerios   110     2    25  29.509541
# 1              Apple Jacks   110     2    25  33.174094
# 2                  Basic 4   130     3    25  37.038562

# %%
df+df2
# Out:
#                                col1   col2  col3  col4       col5
# 0  100% BranApple Cinnamon Cheerios  180.0   6.0  50.0  97.912514
# 1      100% Natural BranApple Jacks  230.0   5.0  25.0  67.157773
# 2                   All-BranBasic 4  200.0   7.0  50.0  96.464067
# 3                               NaN    NaN   NaN   NaN        NaN
# 4                               NaN    NaN   NaN   NaN        NaN
# 5                               NaN    NaN   NaN   NaN        NaN
# 6                               NaN    NaN   NaN   NaN        NaN
# 7                               NaN    NaN   NaN   NaN        NaN
# 8                               NaN    NaN   NaN   NaN        NaN
# 9                               NaN    NaN   NaN   NaN        NaN

# %%
pd.concat([df,df2],ignore_index=True)
# Out:
#                          col1  col2  col3  col4       col5
# 0                   100% Bran    70     4    25  68.402973
# 1           100% Natural Bran   120     3     0  33.983679
# 2                    All-Bran    70     4    25  59.425505
# 3   All-Bran with Extra Fiber    50     4    25  93.704912
# 4                 corn flakes   100     5    25  67.890000
# 5     Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                 Apple Jacks   110     2    25  33.174094
# 7                     Basic 4   130     3    25  37.038562
# 8                   Bran Chex    90     2    25  49.120253
# 9                 Bran Flakes    90     3    25  53.313813
# 10    Apple Cinnamon Cheerios   110     2    25  29.509541
# 11                Apple Jacks   110     2    25  33.174094
# 12                    Basic 4   130     3    25  37.038562

# %%
pd.concat([df,df2])
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                corn flakes   100     5    25  67.890000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813
# 0    Apple Cinnamon Cheerios   110     2    25  29.509541
# 1                Apple Jacks   110     2    25  33.174094
# 2                    Basic 4   130     3    25  37.038562
